# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# folder_path = '../data/omv/CCS/testdrive1'
folder_path = '..\\data\\omv\\CCS\\testdrive1\\datfiles\\rst_npy'

# %%
#property options: SG, PRES, VERDSPLGEO, GEORTYPE
# arr = np.load(os.path.join(folder_path, 'case1_VERDSPLGEO.npy')) 
arr = np.load(os.path.join(folder_path, 'case1_GEORTYPE.npy'))
arr.shape
# Out:
# (100, 100, 11, 6)

# %%
prop = "SG"; layer = 1; year = 2034 #2024, 26, 28, 30, 32, 34
arr = np.load(os.path.join(folder_path, f'case1_{prop}.npy')) #SG, PRES, VERDSPLGEO
plt.imshow(arr[:,:,layer-1,int((year-2024)/2)], origin='lower', cmap='viridis', interpolation=None, aspect='auto', vmin=0, vmax=1)
#plt.imshow(val_new, extent=[x_new.min(), x_new.max(), y_new.min(), y_new.max()], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label="Saturation")
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'{year} layer {layer}')
plt.show()

# %%
prop = "PRES"; layer = 11; year = 2034 #2024, 26, 28, 30, 32, 34
arr = np.load(os.path.join(folder_path, f'case1_{prop}.npy')) #SG, PRES, VERDSPLGEO
plt.imshow(arr[:,:,layer-1,int((year-2024)/2)]/1000, origin='lower', cmap='viridis', interpolation=None, aspect='auto', vmin=16, vmax=36)
#plt.imshow(val_new, extent=[x_new.min(), x_new.max(), y_new.min(), y_new.max()], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label="Pressure (MPa)")
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'{year} layer {layer}')
plt.show()

# %%
prop = "VERDSPLGEO"; layer = 1; year = 2034 #2024, 26, 28, 30, 32, 34
arr = np.load(os.path.join(folder_path, f'case1_{prop}_modified.npy')) 
plt.imshow(arr[:,:,layer-1,int((year-2024)/2)]*1000, origin='lower', cmap='viridis', interpolation=None, aspect='auto', vmin=None, vmax=None)
#plt.imshow(val_new, extent=[x_new.min(), x_new.max(), y_new.min(), y_new.max()], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label="Vertical displacement (mm)")
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'{year} layer {layer}')
plt.show()

# %%
prop = "GEORTYPE"; layer = 10; year = 2034 #2024, 26, 28, 30, 32, 34
arr = np.load(os.path.join(folder_path, f'case1_{prop}_modified.npy')) #SG, PRES, VERDSPLGEO
plt.imshow(arr[:,:,layer-1,int((year-2024)/2)], origin='lower', cmap='viridis', interpolation=None, aspect='auto', vmin=0, vmax=2)
#plt.imshow(val_new, extent=[x_new.min(), x_new.max(), y_new.min(), y_new.max()], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label="Rock Type")
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'{year} layer {layer}')
plt.show()

# %% [markdown]
# # debug

# %%
arr[20,18,5,4]
# Out:
# nan
