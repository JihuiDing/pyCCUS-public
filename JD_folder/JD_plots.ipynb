# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# folder_path = '../data/omv/CCS/testdrive1'
folder_path = '..\\data\\omv\\CCS\\testdrive1\\datfiles\\rst_npy'

# %%
# arr = np.load(os.path.join(folder_path, 'case1_VERDSPLGEO.npy')) #SG, PRES, VERDSPLGEO
arr = np.load(os.path.join(folder_path, 'case1_SG.npy')) #SG, PRES, VERDSPLGEO
arr.shape
# Out:
# (100, 100, 11, 6)

# %%
plt.imshow(arr[:,:,0,5], origin='lower', cmap='viridis', interpolation=None, aspect='auto', vmin=None, vmax=None)
#plt.imshow(val_new, extent=[x_new.min(), x_new.max(), y_new.min(), y_new.max()], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label='Value')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2034')
plt.show()

# %%
plt.imshow(arr[:,:,0,2], cmap='viridis', interpolation=None, aspect='auto', vmin=None, vmax=None)
#plt.imshow(val_new, extent=[x_new.min(), x_new.max(), y_new.min(), y_new.max()], origin='lower', cmap='viridis', aspect='auto')
plt.colorbar(label='Value')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Heatmap')
plt.show()
